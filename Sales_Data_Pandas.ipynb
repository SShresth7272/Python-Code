# %% [markdown]
# <a href="https://colab.research.google.com/github/SShresth7272/Python-Code/blob/main/Sales_Data_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-be4223f6-6f24-4b37-8cd6-ebd1e1c745e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be4223f6-6f24-4b37-8cd6-ebd1e1c745e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['sales_data_sample.csv']))

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2823, step=1)

# %%
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  05/07/2003 0:00  Shipped       2         5     2003  ...
# 2  07/01/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.tail(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/02/2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820  03/01/2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822  05/06/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
df.drop(columns=['QUANTITYORDERED'])
# Out:
#       ORDERNUMBER  PRICEEACH  ORDERLINENUMBER    SALES        ORDERDATE  \
# 0           10107      95.70                2  2871.00   2/24/2003 0:00
# 1           10121      81.35                5  2765.90  05/07/2003 0:00
# 2           10134      94.74                2  3884.34  07/01/2003 0:00
# 3           10145      83.26                6  3746.70   8/25/2003 0:00
# 4           10159     100.00               14  5205.27  10/10/2003 0:00
# ...           ...        ...              ...      ...              ...
# 2818        10350     100.00               15  2244.40  12/02/2004 0:00
# 2819        10373     100.00                1  3978.51   1/31/2005 0:00
# 2820        10386     100.00                4  5417.57  03/01/2005 0:00
# 2821        10397      62.24                1  2116.16   3/28/2005 0:00
# 2822        10414      65.52                9  3079.44  05/06/2005 0:00
#
#         STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  \
# ...

# %%
df[df['ORDERLINENUMBER']==2]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 2           10134               41      94.74                2  3884.34
# 8           10201               22      98.57                2  2168.54
# 12          10251               28     100.00                2  3188.64
# 13          10263               34     100.00                2  3676.76
# ...           ...              ...        ...              ...      ...
# 2745        10131               26      85.13                2  2213.38
# 2749        10178               45      76.25                2  3431.25
# 2750        10198               40      63.67                2  2546.80
# 2752        10222               43      74.03                2  3183.29
# 2798        10117               50      43.68                2  2184.00
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.iloc[256, 5]
# Out:
# '9/30/2004 0:00'

# %%
# Select rows where the 'COUNTRY' is 'USA' using .loc
usa_sales = df.loc[df['COUNTRY'] == 'USA']
display(usa_sales.head())
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 8        10201               22      98.57                2  2168.54
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
# 5  10/28/2003 0:00  Shipped       4        10     2003  ...
# 8  12/01/2003 0:00  Shipped       4        12     2003  ...
#
#                 ADDRESSLINE1  ADDRESSLINE2           CITY STATE POSTALCODE  \
# 0    897 Long Airport Avenue           NaN            NYC    NY      10022
# ...

# %%
df.groupby('QUANTITYORDERED')['SALES'].sum()
# Out:
# QUANTITYORDERED
# 6       1326.78
# 10      1973.60
# 11      1617.44
# 12      1961.28
# 13      1057.29
# 15      3328.95
# 16      1207.68
# 18      4501.62
# 19      4625.36
# 20    192172.60
# 21    215406.03
# 22    224993.12
# 23    174389.68
# 24    220617.84
# 25    232165.25
# 26    251397.90
# 27    290757.06
# 28    224454.44
# 29    282519.74
# 30    211356.00
# 31    278135.41
# 32    289364.80
# 33    314508.48
# 34    375930.52
# 35    230680.10
# 36    328273.92
# 37    326312.25
# 38    361377.34
# 39    308742.72
# 40    305109.20
# 41    441080.87
# 42    314140.26
# 43    380780.87
# 44    383114.16
# 45    435189.15
# 46    479822.28
# 47    351746.61
# 48    446526.74
# 49    447756.61
# 50    344809.00
# 51     18230.46
# 52      4219.28
# 54     13133.34
# 55     88818.95
# 56     16695.84
# 58      7307.42
# 59     18036.89
# 60     21875.40
# 61     14685.75
# 62      4819.26
# 64     16080.64
# 65     10468.90
# 66     38607.36
# 70     17738.00
# ...
