# %% [markdown]
# <a href="https://colab.research.google.com/github/SShresth7272/Python-Code/blob/main/Groupby_and_Aggregation_in_Pandas_PracticeSheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-67920860-ccaa-4fce-82ce-80a7339c58bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67920860-ccaa-4fce-82ce-80a7339c58bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['sales_data_sample.csv']))

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  05/07/2003 0:00  Shipped       2         5     2003  ...
# ...

# %%
df.tail(10)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2813        10293               32      60.06                1  1921.92
# 2814        10306               35      59.51                6  2082.85
# 2815        10315               40      55.69                5  2227.60
# 2816        10327               37      86.74                4  3209.38
# 2817        10337               42      97.16                5  4080.72
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2813  09/09/2004 0:00   Shipped       3         9     2004  ...
# ...

# %%
df.groupby('SALES').agg('sum')
# Out:
#           ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# SALES
# 482.13          10425               11      43.83                6
# 541.14          10407                6      90.19                3
# 553.95          10408               15      36.93                1
# 577.60          10280               20      28.88               12
# 640.05          10419               15      42.67                7
# ...               ...              ...        ...              ...
# 11886.60        10403               66     100.00                9
# 11887.80        10412               60     100.00                9
# 12001.00        10424               50     100.00                6
# 12536.50        10322               50     100.00                6
# 14082.80        10407               76     100.00                2
#
#                 ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  \
# SALES
# 482.13     5/31/2005 0:00  In Process       2         5     2005
# ...

# %%
df.groupby('PRICEEACH').agg('min', numeric_only=True)
# Out:
#            ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER    SALES  QTR_ID  \
# PRICEEACH
# 26.88            10420               45                1  1209.60       2
# 27.22            10162               37                5  1007.14       4
# 28.29            10195               32                7   905.28       4
# 28.88            10280               20               12   577.60       3
# 29.21            10193               26                6   759.46       1
# ...                ...              ...              ...      ...     ...
# 99.69            10339               29               14  2891.01       4
# 99.72            10210               26               14  2592.72       1
# 99.82            10122               25                7  2495.50       1
# 99.91            10107               39                5  3896.49       1
# 100.00           10100                6                1   785.64       1
#
#            MONTH_ID  YEAR_ID  MSRP
# PRICEEACH
# ...

# %%
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  05/07/2003 0:00  Shipped       2         5     2003  ...
# 2  07/01/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.groupby('CITY')['SALES'].agg(['sum', 'mean', 'max'])
# Out:
#                     sum         mean       max
# CITY
# Aaarhus       100595.55  3725.761111   7975.44
# Allentown     122138.14  3939.940000   7962.24
# Barcelona      78411.86  3409.211304   6482.85
# Bergamo       137955.72  2874.077500   5279.40
# Bergen        111640.28  3849.664828   8714.70
# ...                 ...          ...       ...
# Toulouse       70488.44  3524.422000   8331.61
# Tsawassen      74634.85  2870.571154   5795.54
# Vancouver      75238.92  3419.950909   9064.89
# Versailles     64834.32  3601.906667  10172.70
# White Plains   85555.99  3290.615000   7620.50
#
# [73 rows x 3 columns]

# %%
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  05/07/2003 0:00  Shipped       2         5     2003  ...
# 2  07/01/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.info()  df.groupby('PRICEEACH').agg({'B': ['min', 'max'], 'C': 'sum'})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  05/07/2003 0:00  Shipped       2         5     2003  ...
# 2  07/01/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.groupby('PRICEEACH').agg({'QUANTITYORDERED': ['min', 'max'], 'SALES': 'sum'})
# Out:
#           QUANTITYORDERED           SALES
#                       min max         sum
# PRICEEACH
# 26.88                  45  45     1209.60
# 27.22                  37  37     1007.14
# 28.29                  32  32      905.28
# 28.88                  20  20      577.60
# 29.21                  26  42     1986.28
# ...                   ...  ..         ...
# 99.69                  29  29     2891.01
# 99.72                  26  26     2592.72
# 99.82                  25  37     6188.84
# 99.91                  39  39     3896.49
# 100.00                  6  76  6338042.06
#
# [1016 rows x 3 columns]
