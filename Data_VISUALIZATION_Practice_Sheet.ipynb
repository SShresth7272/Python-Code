# %% [markdown]
# <a href="https://colab.research.google.com/github/SShresth7272/Python-Code/blob/main/Data_VISUALIZATION_Practice_Sheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {
    "Category" : ["Electronics", "Clothing", "Groceries", "Clothing","Electronics","Groceries"],
    "Sales": [200,250,150,100,220,130],
    "Date":pd.to_datetime(["2025-01-01","2025-01-02","2025-01-03","2025-01-04","2025-01-05","2025-01-06"])
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Category  Sales       Date
# 0  Electronics    200 2025-01-01
# 1     Clothing    250 2025-01-02
# 2    Groceries    150 2025-01-03
# 3     Clothing    100 2025-01-04
# 4  Electronics    220 2025-01-05
# 5    Groceries    130 2025-01-06

# %%
#matplotlib and seaborn
# Bar Chart
import matplotlib.pyplot as plt
import seaborn as sns

#matplot
bars = plt.bar(df["Category"],df["Sales"],color="green")
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x()+bar.get_width()/3,yval,str(yval),ha="center",va="top")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.title("Sales by Category")
plt.show()

# %%
plt.figure(figsize=(3,4))
sns.barplot(x="Category",y="Sales",data=df, palette=["red","blue","Green"])
plt.show()
# Out:
# /tmp/ipython-input-3662474923.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Category",y="Sales",data=df, palette=["red","blue","Green"])

# %%
sns.lineplot(x="Date",y="Sales",data=df,marker="o")
for x,y in zip(df["Date"],df["Sales"]):
    plt.text(x,y,str(y),ha="center",va='bottom')
plt.show()

# %%
data = {"Date":["2025-01-01","2025-01-02","2025-01-03","2025-01-04"],
        "Sales":[100,180,200,250],
        #"Category":["Electronics","Clothing","Electronics","Clothing"],
    "Electronics":[12,13,14,15],
        "Clothing":[34,78,90,100],
        "Toys":[67,89,45,56]}

df = pd.DataFrame(data)
print(df)
# Out:
#          Date  Sales  Electronics  Clothing  Toys
# 0  2025-01-01    100           12        34    67
# 1  2025-01-02    180           13        78    89
# 2  2025-01-03    200           14        90    45
# 3  2025-01-04    250           15       100    56

# %%
plt.plot(df["Sales"],df["Electronics"],label="Electronics")
plt.plot(df["Sales"],df["Clothing"],label="Clothing")
plt.plot(df["Sales"],df["Toys"],label="Toys")
plt.legend()
plt.show()

# %%
# Melt the DataFrame to long format for plotting multiple lines
df_melted = df.melt(id_vars=["Date"], value_vars=["Electronics", "Clothing", "Toys"], var_name="Category", value_name="Sales_Category")

sns.lineplot(x="Date", y="Sales_Category", hue="Category", data=df_melted, marker="o")
plt.title("Sales by Category Over Time")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %%
# Calculate total sales for each category
category_sales = df_melted.groupby('Category')['Sales_Category'].sum().reset_index()

# Find the category with the highest sales
highest_sales_category = category_sales.loc[category_sales['Sales_Category'].idxmax()]

print("Total Sales by Category:")
display(category_sales)

print("\nCategory with the Highest Sales:")
display(highest_sales_category)
# Out:
# Total Sales by Category:
#       Category  Sales_Category
# 0     Clothing             302
# 1  Electronics              54
# 2         Toys             257
# Category with the Highest Sales:
# Category          Clothing
# Sales_Category         302
# Name: 0, dtype: object
