# %% [markdown]
# <a href="https://colab.research.google.com/github/SShresth7272/Python-Code/blob/main/Python_Pandas_Practice_Sheet_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['bi(7).csv']))
# Out:
#      <input type="file" id="files-9af9998d-70d7-4349-ba01-d184d69ea366" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9af9998d-70d7-4349-ba01-d184d69ea366">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.isna()
# Out:
#     fNAME  lNAME    Age  gender  country  residence  entryEXAM  prevEducation  \
# 0   False  False  False   False    False      False      False          False
# 1   False  False  False   False    False      False      False          False
# 2   False  False  False   False    False      False      False          False
# 3   False  False  False   False    False      False      False          False
# 4   False  False  False   False    False      False      False          False
# ..    ...    ...    ...     ...      ...        ...        ...            ...
# 72  False  False  False   False    False      False      False          False
# 73  False  False  False   False    False      False      False          False
# 74  False  False  False   False    False      False      False          False
# 75  False  False  False   False    False      False      False          False
# 76  False  False  False   False    False      False      False          False
#
#     studyHOURS  Python     DB
# ...

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['MissingData.csv']))
# Out:
#      <input type="file" id="files-c0226b5d-0d91-4050-beb1-5dd7b7cdfcf4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0226b5d-0d91-4050-beb1-5dd7b7cdfcf4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.isna()
# Out:
#        id   name  email  date_joined  price_category  last_purchase_amount
# 0   False  False  False        False           False                 False
# 1   False  False  False        False           False                 False
# 2   False  False  False        False           False                 False
# 3   False  False  False        False           False                 False
# 4   False  False  False        False           False                 False
# 5   False  False  False        False           False                 False
# 6   False  False  False         True           False                 False
# 7   False  False  False        False           False                 False
# 8   False   True  False        False           False                  True
# 9   False  False  False        False           False                 False
# 10  False  False  False        False           False                 False
# ...

# %%
df.isna().sum()
# Out:
# id                      0
# name                    1
# email                   0
# date_joined             1
# price_category          0
# last_purchase_amount    1
# dtype: int64

# %%
df.dropna()
# Out:
#     id            name                      email date_joined price_category  \
# 0    1     alice smith    alice.smith@example.com  2022-01-15            mid
# 1    2     Bob Johnson    bob.johnson@example.com  2022/02/30           high
# 2    3  Carol Williams        carol.w@example.com  2022-03-10            low
# 3    4      dave jones     DAVE.JONES@example.com  2022-04-05            MID
# 4    5       Eve Brown      eve.brown@example.com  2022-05-20           high
# 5    2     Bob Johnson    bob.johnson@example.com  2022/02/30           high
# 7    7     Grace Davis    grace.davis@example.com  2022-07-01           high
# 9    9      Ivy Garcia     ivy.garcia@example.com  2022-09-22            mid
# 10  10     Jack Wilson    jack.wilson@example.com  2022-10-10           high
# 11  11       Karen Lee      karen.lee@example.com  2022-11-05            low
# 12  12     alice smith    alice.smith@example.com  2022-01-15            mid
# ...

# %%
df.fillna(6)
# Out:
#     id            name                      email date_joined price_category  \
# 0    1     alice smith    alice.smith@example.com  2022-01-15            mid
# 1    2     Bob Johnson    bob.johnson@example.com  2022/02/30           high
# 2    3  Carol Williams        carol.w@example.com  2022-03-10            low
# 3    4      dave jones     DAVE.JONES@example.com  2022-04-05            MID
# 4    5       Eve Brown      eve.brown@example.com  2022-05-20           high
# 5    2     Bob Johnson    bob.johnson@example.com  2022/02/30           high
# 6    6    Frank Miller   frank.miller@example.com           6            low
# 7    7     Grace Davis    grace.davis@example.com  2022-07-01           high
# 8    8               6   henry.wilson@example.com  2022-08-18            low
# 9    9      Ivy Garcia     ivy.garcia@example.com  2022-09-22            mid
# 10  10     Jack Wilson    jack.wilson@example.com  2022-10-10           high
# ...

# %%
df.fillna(7)
# Out:
#     id            name                      email date_joined price_category  \
# 0    1     alice smith    alice.smith@example.com  2022-01-15            mid
# 1    2     Bob Johnson    bob.johnson@example.com  2022/02/30           high
# 2    3  Carol Williams        carol.w@example.com  2022-03-10            low
# 3    4      dave jones     DAVE.JONES@example.com  2022-04-05            MID
# 4    5       Eve Brown      eve.brown@example.com  2022-05-20           high
# 5    2     Bob Johnson    bob.johnson@example.com  2022/02/30           high
# 6    6    Frank Miller   frank.miller@example.com           7            low
# 7    7     Grace Davis    grace.davis@example.com  2022-07-01           high
# 8    8               7   henry.wilson@example.com  2022-08-18            low
# 9    9      Ivy Garcia     ivy.garcia@example.com  2022-09-22            mid
# 10  10     Jack Wilson    jack.wilson@example.com  2022-10-10           high
# ...

# %%
df['name'].fillna("Prince", inplace=True)
df
# Out:
# /tmp/ipython-input-189268038.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['name'].fillna("Prince", inplace=True)
#     id            name                      email date_joined price_category  \
# 0    1     alice smith    alice.smith@example.com  2022-01-15            mid
# 1    2     Bob Johnson    bob.johnson@example.com  2022/02/30           high
# 2    3  Carol Williams        carol.w@example.com  2022-03-10            low
# 3    4      dave jones     DAVE.JONES@example.com  2022-04-05            MID
# ...

# %%
df['date_joined'].fillna("2025-13-45	", inplace=True)
df
# Out:
# /tmp/ipython-input-2028909595.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['date_joined'].fillna("2025-13-45	", inplace=True)
#     id            name                      email   date_joined  \
# 0    1     alice smith    alice.smith@example.com    2022-01-15
# 1    2     Bob Johnson    bob.johnson@example.com    2022/02/30
# 2    3  Carol Williams        carol.w@example.com    2022-03-10
# 3    4      dave jones     DAVE.JONES@example.com    2022-04-05
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#     id            name                      email   date_joined  \
# 0    1     alice smith    alice.smith@example.com    2022-01-15
# 1    2     Bob Johnson    bob.johnson@example.com    2022/02/30
# 2    3  Carol Williams        carol.w@example.com    2022-03-10
# 3    4      dave jones     DAVE.JONES@example.com    2022-04-05
# 4    5       Eve Brown      eve.brown@example.com    2022-05-20
# 6    6    Frank Miller   frank.miller@example.com  2025-13-45\t
# 7    7     Grace Davis    grace.davis@example.com    2022-07-01
# 8    8          Prince   henry.wilson@example.com    2022-08-18
# 9    9      Ivy Garcia     ivy.garcia@example.com    2022-09-22
# 10  10     Jack Wilson    jack.wilson@example.com    2022-10-10
# 11  11       Karen Lee      karen.lee@example.com    2022-11-05
# 12  12     alice smith    alice.smith@example.com    2022-01-15
# 13  13      Mike Clark    mike.clarck@example.com    2022-12-12
# 14  14      Nina Lopez     nina.lopez@example.com    2022-13-45
# ...

# %%
df['name'].str.upper()
# Out:
# 0        ALICE SMITH
# 1        BOB JOHNSON
# 2     CAROL WILLIAMS
# 3         DAVE JONES
# 4          EVE BROWN
# 5        BOB JOHNSON
# 6       FRANK MILLER
# 7        GRACE DAVIS
# 8             PRINCE
# 9         IVY GARCIA
# 10       JACK WILSON
# 11         KAREN LEE
# 12       ALICE SMITH
# 13        MIKE CLARK
# 14        NINA LOPEZ
# 15     OLIVER TAYLOR
# Name: name, dtype: object

# %%
df['email'].str.contains('mike.clarck@example.com')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# Name: email, dtype: bool

# %%
 df.rename(columns={'last_purchase_amount': 'first_purchase_amount'}) #Renaming Columns
# Out:
#     id            name                      email   date_joined  \
# 0    1     alice smith    alice.smith@example.com    2022-01-15
# 1    2     Bob Johnson    bob.johnson@example.com    2022/02/30
# 2    3  Carol Williams        carol.w@example.com    2022-03-10
# 3    4      dave jones     DAVE.JONES@example.com    2022-04-05
# 4    5       Eve Brown      eve.brown@example.com    2022-05-20
# 5    2     Bob Johnson    bob.johnson@example.com    2022/02/30
# 6    6    Frank Miller   frank.miller@example.com  2025-13-45\t
# 7    7     Grace Davis    grace.davis@example.com    2022-07-01
# 8    8          Prince   henry.wilson@example.com    2022-08-18
# 9    9      Ivy Garcia     ivy.garcia@example.com    2022-09-22
# 10  10     Jack Wilson    jack.wilson@example.com    2022-10-10
# 11  11       Karen Lee      karen.lee@example.com    2022-11-05
# 12  12     alice smith    alice.smith@example.com    2022-01-15
# 13  13      Mike Clark    mike.clarck@example.com    2022-12-12
# ...

# %%
df['last_purchase_amount'] = [50.23,45.21,78,89,56,23,12,4,5,78,56,56,89,45,78,75]
df
# Out:
#     id            name                      email   date_joined  \
# 0    1     alice smith    alice.smith@example.com    2022-01-15
# 1    2     Bob Johnson    bob.johnson@example.com    2022/02/30
# 2    3  Carol Williams        carol.w@example.com    2022-03-10
# 3    4      dave jones     DAVE.JONES@example.com    2022-04-05
# 4    5       Eve Brown      eve.brown@example.com    2022-05-20
# 5    2     Bob Johnson    bob.johnson@example.com    2022/02/30
# 6    6    Frank Miller   frank.miller@example.com  2025-13-45\t
# 7    7     Grace Davis    grace.davis@example.com    2022-07-01
# 8    8          Prince   henry.wilson@example.com    2022-08-18
# 9    9      Ivy Garcia     ivy.garcia@example.com    2022-09-22
# 10  10     Jack Wilson    jack.wilson@example.com    2022-10-10
# 11  11       Karen Lee      karen.lee@example.com    2022-11-05
# 12  12     alice smith    alice.smith@example.com    2022-01-15
# 13  13      Mike Clark    mike.clarck@example.com    2022-12-12
# ...
